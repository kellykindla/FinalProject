# %%
import pandas as pd

# %%
data = pd.read_csv('Resources/Crime_Reports.csv')
# Out:
# C:\Users\Philip\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.sample(10)
# Out:
#          Incident Number     Highest Offense Description  \
# 1814687      20125042678             BURGLARY OF VEHICLE
# 851564       20103551079             FORGERY AND PASSING
# 1295495      20113441763      POSS OF DRUG PARAPHERNALIA
# 583344       20082711820              FAMILY DISTURBANCE
# 785745       20075005748             BURGLARY OF VEHICLE
# 579016       20173471199            THEFT BY SHOPLIFTING
# 698266       20105022010                           THEFT
# 2350251      20072541885  ASSAULT W/INJURY-FAM/DATE VIOL
# 1604237      20141440416              FAMILY DISTURBANCE
# 41573        20072721283             BURGLARY OF VEHICLE
#
#          Highest Offense Code Family Violence      Occurred Date Time  \
# 1814687                   601               N  09/22/2012 12:00:00 PM
# 851564                   1000               N  12/20/2010 02:00:00 PM
# 1295495                  1818               N  12/10/2011 10:44:00 PM
# ...

# %%
data.dtypes
# Out:
# Incident Number                  int64
# Highest Offense Description     object
# Highest Offense Code             int64
# Family Violence                 object
# Occurred Date Time              object
# Occurred Date                   object
# Occurred Time                  float64
# Report Date Time                object
# Report Date                     object
# Report Time                    float64
# Location Type                   object
# Address                         object
# Zip Code                       float64
# Council District               float64
# APD Sector                      object
# APD District                    object
# PRA                             object
# Census Tract                   float64
# Clearance Status                object
# Clearance Date                  object
# UCR Category                    object
# Category Description            object
# X-coordinate                   float64
# Y-coordinate                   float64
# ...

# %%
data['Highest Offense Description'].unique()
# Out:
# array(['PROTECTIVE ORDER', 'RAPE', 'DOC EXPOSURE', 'RUNAWAY CHILD',
#        'POSSESSION OF MARIJUANA', 'EVADING / FOOT',
#        'BURGLARY OF RESIDENCE', 'DISTURBANCE - OTHER',
#        'POSS CONTROLLED SUB/NARCOTIC', 'CRIMINAL MISCHIEF',
#        'IDENTITY THEFT', 'FAMILY DISTURBANCE', 'DWI',
#        'INDECENCY WITH A CHILD/CONTACT', 'VIOL CITY ORDINANCE - DOG',
#        'DATING DISTURBANCE', 'THEFT', 'THEFT OF BICYCLE', 'FRAUD - OTHER',
#        'CRIMINAL TRESPASS', 'ASSAULT W/INJURY-FAM/DATE VIOL',
#        'HARASSMENT', 'AGG ASSAULT', 'SUSPICIOUS PERSON',
#        'DAMAGE CITY PROP', 'RAPE OF A CHILD',
#        'ASSAULT  CONTACT-SEXUAL NATURE', 'ASSAULT BY CONTACT FAM/DATING',
#        'TERRORISTIC THREAT', 'THEFT BY SHOPLIFTING',
#        'ASSAULT WITH INJURY', 'SEXUAL ASSAULT OF CHILD/OBJECT',
#        'WARRANT ARREST NON TRAFFIC', 'POSS OF DRUG PARAPHERNALIA',
#        'BURGLARY OF VEHICLE', 'POSS OF PROHIBITED WEAPON',
# ...

# %%
data['Occurred Date Time'].sort_values(ascending=False)
# Out:
# 544609     12/31/2021 12:56:00 PM
# 556587     12/31/2021 12:56:00 PM
# 550111     12/31/2021 12:55:00 PM
# 544222     12/31/2021 12:47:00 PM
# 545612     12/31/2021 12:46:00 PM
#                     ...
# 2353080                       NaN
# 2381248                       NaN
# 2382292                       NaN
# 2393380                       NaN
# 2400916                       NaN
# Name: Occurred Date Time, Length: 2407387, dtype: object
